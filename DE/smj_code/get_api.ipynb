# %%
import requests
import json
import datetime
import time
import yaml
import pandas as pd

# %%
with open('C:/Users/cc843/Desktop/辛旻宗/주식프로젝트/key/config.yaml', encoding='UTF-8') as f:
    _cfg = yaml.load(f, Loader=yaml.FullLoader)
APP_KEY = _cfg['APP_KEY']
APP_SECRET = _cfg['APP_SECRET']
ACCESS_TOKEN = ""
CANO = _cfg['CANO']
ACNT_PRDT_CD = _cfg['ACNT_PRDT_CD']
DISCORD_WEBHOOK_URL = _cfg['DISCORD_WEBHOOK_URL']
URL_BASE = _cfg['URL_BASE']

# %%
def get_access_token():
    """토큰 발급"""
    headers = {"content-type": "application/json"}
    body = {"grant_type": "client_credentials", "appkey": APP_KEY, "appsecret": APP_SECRET}
    PATH = "oauth2/tokenP"
    URL = f"{URL_BASE}/{PATH}"
    res = requests.post(URL, headers=headers, data=json.dumps(body))
    ACCESS_TOKEN = res.json()["access_token"]
    return ACCESS_TOKEN

# %%
from datetime import datetime
today = datetime.today()

def get_current_price(code=""):
    """일봉 조회"""
    PATH = "/uapi/domestic-stock/v1/quotations/inquire-daily-itemchartprice"
    URL = f"{URL_BASE}/{PATH}"
    headers = {"Content-Type":"application/json", 
            "authorization": f"Bearer {ACCESS_TOKEN}",
            "appKey":APP_KEY,
            "appSecret":APP_SECRET,
            "tr_id":"FHKST01010100"}
    params = {
    "fid_cond_mrkt_div_code":"J", # 시장 분류 코드 
    "fid_input_iscd":code, # 종목 코드
    #"fid_input_date_1":"20240301", # 시작 날짜
    #"fid_input_date_2":"20240321",#today.strftime("%Y%m%d"), # 종료 날짜
    "fid_period_div_code": "D", # 기간분류코드 	D:일봉, W:주봉, M:월봉, Y:년봉
    "fid_org_adj_prc":"0"
    }
    res = requests.get(URL, headers=headers, params=params)
    
    return res.json()#['output']#['stck_bsop_date']

# %%
ACCESS_TOKEN = get_access_token()

# %%
current_price  = get_current_price("005930")
print(current_price,end='\n')
# Out:
# {'output': {'iscd_stat_cls_code': '55', 'marg_rate': '20.00', 'rprs_mrkt_kor_name': 'KOSPI200', 'new_hgpr_lwpr_cls_code': '신고가', 'bstp_kor_isnm': '전기.전자', 'temp_stop_yn': 'N', 'oprc_rang_cont_yn': 'N', 'clpr_rang_cont_yn': 'N', 'crdt_able_yn': 'Y', 'grmn_rate_cls_code': '40', 'elw_pblc_yn': 'Y', 'stck_prpr': '78000', 'prdy_vrss': '-1300', 'prdy_vrss_sign': '5', 'prdy_ctrt': '-1.64', 'acml_tr_pbmn': '1435937314000', 'acml_vol': '18219614', 'prdy_vrss_vol_rate': '40.88', 'stck_oprc': '79600', 'stck_hgpr': '79900', 'stck_lwpr': '77900', 'stck_mxpr': '103000', 'stck_llam': '55600', 'stck_sdpr': '79300', 'wghn_avrg_stck_prc': '78811.80', 'hts_frgn_ehrt': '54.85', 'frgn_ntby_qty': '0', 'pgtr_ntby_qty': '-73683', 'pvt_scnd_dmrs_prc': '80366', 'pvt_frst_dmrs_prc': '79832', 'pvt_pont_val': '78766', 'pvt_frst_dmsp_prc': '78232', 'pvt_scnd_dmsp_prc': '77166', 'dmrs_val': '80100', 'dmsp_val': '78500', 'cpfn': '7780', 'rstc_wdth_prc': '23700', 'stck_fcam': '100', 'stck_sspr': '61850', 'aspr_unit': '100', 'hts_deal_qty_unit_val': '1', 'lstn_stcn': '5969782550', 'hts_avls': '4656430', 'per': '36.60', 'pbr': '1.50', 'stac_month': '12', 'vol_tnrt': '0.31', 'eps': '2131.00', 'bps': '52002.00', 'd250_hgpr': '79900', 'd250_hgpr_date': '20240322', 'd250_hgpr_vrss_prpr_rate': '-2.38', 'd250_lwpr': '60100', 'd250_lwpr_date': '20230321', 'd250_lwpr_vrss_prpr_rate': '29.78', 'stck_dryy_hgpr': '79900', 'dryy_hgpr_vrss_prpr_rate': '-2.38', 'dryy_hgpr_date': '20240322', 'stck_dryy_lwpr': '70700', 'dryy_lwpr_vrss_prpr_rate': '10.33', 'dryy_lwpr_date': '20240118', 'w52_hgpr': '79900', 'w52_hgpr_vrss_prpr_ctrt': '-2.38', 'w52_hgpr_date': '20240322', 'w52_lwpr': '60500', 'w52_lwpr_vrss_prpr_ctrt': '28.93', 'w52_lwpr_date': '20230322', 'whol_loan_rmnd_rate': '0.13', 'ssts_yn': 'N', 'stck_shrn_iscd': '005930', 'fcam_cnnm': '100', 'cpfn_cnnm': '7,780 억', 'frgn_hldn_qty': '3274312924', 'vi_cls_code': 'N', 'ovtm_vi_cls_code': 'N', 'last_ssts_cntg_qty': '181754', 'invt_caful_yn': 'N', 'mrkt_warn_cls_code': '00', 'short_over_yn': 'N', 'sltr_yn': 'N'}, 'rt_cd': '0', 'msg_cd': 'MCA00000', 'msg1': '정상처리 되었습니다.'}

# %%
import pandas as pd

# %%
# 전체 데이터를 보여주는 옵션 설정
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)

df = pd.DataFrame(current_price)

df
# Out:
#                                  output rt_cd    msg_cd         msg1
# iscd_stat_cls_code                   55     0  MCA00000  정상처리 되었습니다.
# marg_rate                         20.00     0  MCA00000  정상처리 되었습니다.
# rprs_mrkt_kor_name             KOSPI200     0  MCA00000  정상처리 되었습니다.
# new_hgpr_lwpr_cls_code              신고가     0  MCA00000  정상처리 되었습니다.
# bstp_kor_isnm                     전기.전자     0  MCA00000  정상처리 되었습니다.
# temp_stop_yn                          N     0  MCA00000  정상처리 되었습니다.
# oprc_rang_cont_yn                     N     0  MCA00000  정상처리 되었습니다.
# clpr_rang_cont_yn                     N     0  MCA00000  정상처리 되었습니다.
# crdt_able_yn                          Y     0  MCA00000  정상처리 되었습니다.
# grmn_rate_cls_code                   40     0  MCA00000  정상처리 되었습니다.
# elw_pblc_yn                           Y     0  MCA00000  정상처리 되었습니다.
# stck_prpr                         78000     0  MCA00000  정상처리 되었습니다.
# prdy_vrss                         -1300     0  MCA00000  정상처리 되었습니다.
# prdy_vrss_sign                        5     0  MCA00000  정상처리 되었습니다.
# prdy_ctrt                         -1.64     0  MCA00000  정상처리 되었습니다.
# acml_tr_pbmn              1435937314000     0  MCA00000  정상처리 되었습니다.
# acml_vol                       18219614     0  MCA00000  정상처리 되었습니다.
# prdy_vrss_vol_rate                40.88     0  MCA00000  정상처리 되었습니다.
# stck_oprc                         79600     0  MCA00000  정상처리 되었습니다.
# stck_hgpr                         79900     0  MCA00000  정상처리 되었습니다.
# stck_lwpr                         77900     0  MCA00000  정상처리 되었습니다.
# stck_mxpr                        103000     0  MCA00000  정상처리 되었습니다.
# stck_llam                         55600     0  MCA00000  정상처리 되었습니다.
# stck_sdpr                         79300     0  MCA00000  정상처리 되었습니다.
# wghn_avrg_stck_prc             78811.80     0  MCA00000  정상처리 되었습니다.
# hts_frgn_ehrt                     54.85     0  MCA00000  정상처리 되었습니다.
# frgn_ntby_qty                         0     0  MCA00000  정상처리 되었습니다.
# pgtr_ntby_qty                    -73683     0  MCA00000  정상처리 되었습니다.
# pvt_scnd_dmrs_prc                 80366     0  MCA00000  정상처리 되었습니다.
# pvt_frst_dmrs_prc                 79832     0  MCA00000  정상처리 되었습니다.
# pvt_pont_val                      78766     0  MCA00000  정상처리 되었습니다.
# pvt_frst_dmsp_prc                 78232     0  MCA00000  정상처리 되었습니다.
# pvt_scnd_dmsp_prc                 77166     0  MCA00000  정상처리 되었습니다.
# dmrs_val                          80100     0  MCA00000  정상처리 되었습니다.
# dmsp_val                          78500     0  MCA00000  정상처리 되었습니다.
# cpfn                               7780     0  MCA00000  정상처리 되었습니다.
# rstc_wdth_prc                     23700     0  MCA00000  정상처리 되었습니다.
# stck_fcam                           100     0  MCA00000  정상처리 되었습니다.
# stck_sspr                         61850     0  MCA00000  정상처리 되었습니다.
# aspr_unit                           100     0  MCA00000  정상처리 되었습니다.
# hts_deal_qty_unit_val                 1     0  MCA00000  정상처리 되었습니다.
# lstn_stcn                    5969782550     0  MCA00000  정상처리 되었습니다.
# hts_avls                        4656430     0  MCA00000  정상처리 되었습니다.
# per                               36.60     0  MCA00000  정상처리 되었습니다.
# pbr                                1.50     0  MCA00000  정상처리 되었습니다.
# stac_month                           12     0  MCA00000  정상처리 되었습니다.
# vol_tnrt                           0.31     0  MCA00000  정상처리 되었습니다.
# eps                             2131.00     0  MCA00000  정상처리 되었습니다.
# bps                            52002.00     0  MCA00000  정상처리 되었습니다.
# d250_hgpr                         79900     0  MCA00000  정상처리 되었습니다.
# d250_hgpr_date                 20240322     0  MCA00000  정상처리 되었습니다.
# d250_hgpr_vrss_prpr_rate          -2.38     0  MCA00000  정상처리 되었습니다.
# d250_lwpr                         60100     0  MCA00000  정상처리 되었습니다.
# d250_lwpr_date                 20230321     0  MCA00000  정상처리 되었습니다.
# d250_lwpr_vrss_prpr_rate          29.78     0  MCA00000  정상처리 되었습니다.
# stck_dryy_hgpr                    79900     0  MCA00000  정상처리 되었습니다.
# dryy_hgpr_vrss_prpr_rate          -2.38     0  MCA00000  정상처리 되었습니다.
# dryy_hgpr_date                 20240322     0  MCA00000  정상처리 되었습니다.
# stck_dryy_lwpr                    70700     0  MCA00000  정상처리 되었습니다.
# dryy_lwpr_vrss_prpr_rate          10.33     0  MCA00000  정상처리 되었습니다.
# dryy_lwpr_date                 20240118     0  MCA00000  정상처리 되었습니다.
# w52_hgpr                          79900     0  MCA00000  정상처리 되었습니다.
# w52_hgpr_vrss_prpr_ctrt           -2.38     0  MCA00000  정상처리 되었습니다.
# w52_hgpr_date                  20240322     0  MCA00000  정상처리 되었습니다.
# w52_lwpr                          60500     0  MCA00000  정상처리 되었습니다.
# w52_lwpr_vrss_prpr_ctrt           28.93     0  MCA00000  정상처리 되었습니다.
# w52_lwpr_date                  20230322     0  MCA00000  정상처리 되었습니다.
# whol_loan_rmnd_rate                0.13     0  MCA00000  정상처리 되었습니다.
# ssts_yn                               N     0  MCA00000  정상처리 되었습니다.
# stck_shrn_iscd                   005930     0  MCA00000  정상처리 되었습니다.
# fcam_cnnm                           100     0  MCA00000  정상처리 되었습니다.
# cpfn_cnnm                       7,780 억     0  MCA00000  정상처리 되었습니다.
# frgn_hldn_qty                3274312924     0  MCA00000  정상처리 되었습니다.
# vi_cls_code                           N     0  MCA00000  정상처리 되었습니다.
# ovtm_vi_cls_code                      N     0  MCA00000  정상처리 되었습니다.
# last_ssts_cntg_qty               181754     0  MCA00000  정상처리 되었습니다.
# invt_caful_yn                         N     0  MCA00000  정상처리 되었습니다.
# mrkt_warn_cls_code                   00     0  MCA00000  정상처리 되었습니다.
# short_over_yn                         N     0  MCA00000  정상처리 되었습니다.
# sltr_yn                               N     0  MCA00000  정상처리 되었습니다.
